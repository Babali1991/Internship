# %% [raw]
#  So in this notebook we will scrap data from "https://www.shine.com/new/job-search" website for Data Analyst job role for Banglore location.We will scrap fields for job as mentioned below:
# 1. job title 2. Company name 3. Location of job 4. Experience required

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
#Openings the shine page on automated chrome browser
driver.get("https://www.shine.com/new/job-search")

# %%
# entering designation and location as required in the question-

designation=driver.find_element(By.CLASS_NAME,"form-control")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div/div[1]/div[1]/div/div[2]/div/div/form/div/div[1]/ul/li[2]/div/input")
                             
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
# scraping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]/a')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
    
# scrapping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)
    
# scrapping company name from the given page
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags:
    company=i.text
    company_name.append(company)
    
# scrapping job Experience from the given page
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 20 20 20 20

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                                 Title        Location  \
# 0                                   Lead Data Analyst       Bangalore
# 1                                        Data Analyst   Bangalore\n+3
# 2                            Vacancy For Data Analyst  Bangalore\n+14
# 3                               Clinical Data Analyst   Bangalore\n+6
# 4                                     Data Management  Bangalore\n+18
# 5                                   Data Modeler data       Bangalore
# 6                                       Data Modeller       Bangalore
# 7                              Data Modeler Bangalore       Bangalore
# 8                                        Data Modeler       Bangalore
# 9                               Clinical Data Analyst   Bangalore\n+4
# 10  Full time Opportunity-Networking Advisor-Cisco...   Bangalore\n+5
# 11                                   Data Engineer Ii   Bangalore\n+9
# ...

# %% [markdown]
# So in this notebook we will scrap data from "https://www.shine.com/new/job-search" website for"Data Scientist" job role for Banglore location.We will scrap fields for job as mentioned below:
# 1) job title 2) Company name 3) Location of job

# %%
driver = webdriver.Chrome()

# %%
#Openings the shine page on automated chrome browser
driver.get("https://www.shine.com/new/job-search")

# %%
# entering designation and location as required in the question-

designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div/div[1]/div[1]/div/div[2]/div/div/form/div/div[1]/ul/li[2]/div/input")
                             
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]

# %%
# scraping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]/a')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
    
# scrapping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)
    
# scrapping company name from the given page
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags:
    company=i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(company_name))
# Out:
# 20 20 20

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name})
df
# Out:
#                                                 Title        Location  \
# 0                                   ML Data Scientist   Bangalore\n+3
# 1                       Data Scientist Urgent Vacancy  Bangalore\n+15
# 2                          Data Scientist Recruitment  Bangalore\n+15
# 3                          Data Scientist Recruitment  Bangalore\n+15
# 4                                      Data Scientist   Bangalore\n+4
# 5                                      Data Scientist       Bangalore
# 6       Lead Data Scientist/ Principal Data Scientist   Bangalore\n+1
# 7   Vacancy For Data Scientist Fresher and Experience  Bangalore\n+14
# 8                               Senior Data Scientist   Bangalore\n+1
# 9                                 Lead Data Scientist   Bangalore\n+1
# 10                                     Data Scientist   Bangalore\n+7
# 11                      Data Scientist Urgent Vacancy  Bangalore\n+14
# ...

# %% [raw]
# So in this notebook we will scrap data from "https://www.shine.com/new/job-search" website for Data Scientist job role for Delhi location.We will scrap fields for job as mentioned below:
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs.
# 1. job title 2. Company name 3. Location of job 4. Experience required

# %%
driver = webdriver.Chrome()

# %%
#Openings the shine page on automated chrome browser
driver.get("https://www.shine.com/new/job-search")

# %%
# entering designation and location as required in the question-

designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div/div[1]/div[1]/div/div[2]/div/div/form/div/div[1]/ul/li[2]/div/input")
                             
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
# scraping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]/a')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
    
# scrapping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)
    
# scrapping company name from the given page
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags:
    company=i.text
    company_name.append(company)
    
# scrapping job Experience from the given page
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 20 20 20 20

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                                 Title    Location  \
# 0                                      Data Scientist   Delhi\n+4
# 1                               Clinical Data Analyst   Delhi\n+6
# 2                             Clinical Sas Programmer   Delhi\n+8
# 3                                        Clinical SAS   Delhi\n+8
# 4                            Clinical Data Management   Delhi\n+6
# 5                              Bioanalytical Research   Delhi\n+6
# 6                     Junior Clinical Data Management   Delhi\n+6
# 7                   Bioanalytical Research Associates   Delhi\n+6
# 8                                        Clinical SAS   Delhi\n+8
# 9                                       Data Engineer   Delhi\n+9
# 10                                    Biostatistician  Delhi\n+17
# 11                           Clinical Analyst Fresher   Delhi\n+6
# 12                       Clinical Document Specialist   Delhi\n+6
# ...
